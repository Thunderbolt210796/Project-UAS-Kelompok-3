# %% [markdown]
# # Project Akhir Algoritma Pemograman
# ---
# DIV Akuntansi Sektor Publik alih Program Kelas 9 Sistem Informasi
# ---
# Nama : Elzami Haqie Ednoer
#
# NIM/No. Absen  : 4132210005/02
#
# ---
#
# Nama : Intan Permatasari
#
# NIM/No. Absen  : 4132210008/06
#
# ---
#
# Nama : Ramiz Firas
#
# NIM/No. Absen  : 4132210052/09

# %% [markdown]
# ## Latar belakang

# %% [markdown]
# - target PDB
# - kecenderungan tren naik dengan adanya anomali spt misal 2020 apakah tercermin
# - apakah target tercermin melalui model prediksi yang tetap menangkap anomali

# %% [markdown]
# ## Import Library yang dibutuhkan selama project berlangsung

# %%
import pandas as pd
import numpy as np
import missingno

#import package for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter('ignore')
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_predict
import pmdarima as pm

# %% [markdown]
# ## Import Dataset yang akan digunakan untuk project

# %%
GDP = pd.read_csv("gdp 1960-2022.csv")
Population = pd.read_csv("population 1960-2021.csv")

# %%
GDP
# Out:
#        Jenis Pengeluaran  \
# 0                    NaN
# 1  PRODUK DOMESTIK BRUTO
#
#    [Seri 1960] 1. PDB Atas Dasar Harga Berlaku Menurut Pengeluaran (Milyar Rupiah)  \
# 0                                               1972
# 1                                               4548
#
#    Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0        1971      1970.0      1969.0      1968.0      1967.0      1966.0
# 1        3794      3340.2      2718.3      2096.7       847.8       315.9
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0        1965      1964.0  ...       2019.0         2018       2017.0
# 1       23710      7133.5  ...   15832657.2     14838756   13589825.7
#
#    Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 0       2016.0       2015.0       2014.0         2013       2012.0
# 1   12401728.5   11526332.8   10569705.3      9546134    8615704.5
#
#    Unnamed: 62  Unnamed: 63
# 0         2011       2010.0
# 1      7831726    6864133.1
#
# [2 rows x 64 columns]

# %%
Population
# Out:
#   Country Name Country Code     Indicator Name Indicator Code      1960  \
# 0    Indonesia          IDN  Population, total    SP.POP.TOTL  88382881
#
#        1961      1962      1963      1964       1965  ...       2012  \
# 0  90816938  93345489  95962527  98675061  101157868  ...  250222695
#
#         2013       2014       2015       2016       2017       2018  \
# 0  253275918  256229761  259091970  261850182  264498852  267066843
#
#         2019       2020       2021
# 0  269582878  271857970  273753191
#
# [1 rows x 66 columns]

# %% [markdown]
# ## Preprocessing Data

# %% [markdown]
# #### Transpose Data

# %%
#Data yang telah di import kemudian di Tranpose untuk memenuhi kebutuhan terhadap bentuk data selama project
GDP = GDP.transpose()
Population = Population.transpose()

# %%
GDP
# Out:
#                                                          0  \
# Jenis Pengeluaran                                      NaN
# [Seri 1960] 1. PDB Atas Dasar Harga Berlaku Men...    1972
# Unnamed: 2                                            1971
# Unnamed: 3                                          1970.0
# Unnamed: 4                                          1969.0
# ...                                                    ...
# Unnamed: 59                                         2014.0
# Unnamed: 60                                           2013
# Unnamed: 61                                         2012.0
# Unnamed: 62                                           2011
# Unnamed: 63                                         2010.0
#
#                                                                         1
# Jenis Pengeluaran                                   PRODUK DOMESTIK BRUTO
# [Seri 1960] 1. PDB Atas Dasar Harga Berlaku Men...                   4548
# Unnamed: 2                                                           3794
# Unnamed: 3                                                         3340.2
# Unnamed: 4                                                         2718.3
# ...                                                                   ...
# Unnamed: 59                                                    10569705.3
# Unnamed: 60                                                       9546134
# Unnamed: 61                                                     8615704.5
# Unnamed: 62                                                       7831726
# Unnamed: 63                                                     6864133.1
#
# [64 rows x 2 columns]

# %%
Population
# Out:
#                                 0
# Country Name            Indonesia
# Country Code                  IDN
# Indicator Name  Population, total
# Indicator Code        SP.POP.TOTL
# 1960                     88382881
# ...                           ...
# 2017                    264498852
# 2018                    267066843
# 2019                    269582878
# 2020                    271857970
# 2021                    273753191
#
# [66 rows x 1 columns]

# %% [markdown]
# ### Mengolah Kolom dan Index

# %%
#Setelah Data di Transpose kemudian mengatus nama kolom dan letak kolom
GDP.columns = ['Tahun', 'GDP']
GDP = GDP[1:]
GDP
# Out:
#                                                      Tahun         GDP
# [Seri 1960] 1. PDB Atas Dasar Harga Berlaku Men...    1972        4548
# Unnamed: 2                                            1971        3794
# Unnamed: 3                                          1970.0      3340.2
# Unnamed: 4                                          1969.0      2718.3
# Unnamed: 5                                          1968.0      2096.7
# ...                                                    ...         ...
# Unnamed: 59                                         2014.0  10569705.3
# Unnamed: 60                                           2013     9546134
# Unnamed: 61                                         2012.0   8615704.5
# Unnamed: 62                                           2011     7831726
# Unnamed: 63                                         2010.0   6864133.1
#
# [63 rows x 2 columns]

# %%
Population = Population[4:]
Population
# Out:
#               0
# 1960   88382881
# 1961   90816938
# 1962   93345489
# 1963   95962527
# 1964   98675061
# ...         ...
# 2017  264498852
# 2018  267066843
# 2019  269582878
# 2020  271857970
# 2021  273753191
#
# [62 rows x 1 columns]

# %%
#Mereset Indeks pada Dataframe yang telah di import

GDP = GDP.reset_index()
Population = Population.reset_index()
GDP
# Out:
#                                                 index   Tahun         GDP
# 0   [Seri 1960] 1. PDB Atas Dasar Harga Berlaku Me...    1972        4548
# 1                                          Unnamed: 2    1971        3794
# 2                                          Unnamed: 3  1970.0      3340.2
# 3                                          Unnamed: 4  1969.0      2718.3
# 4                                          Unnamed: 5  1968.0      2096.7
# ..                                                ...     ...         ...
# 58                                        Unnamed: 59  2014.0  10569705.3
# 59                                        Unnamed: 60    2013     9546134
# 60                                        Unnamed: 61  2012.0   8615704.5
# 61                                        Unnamed: 62    2011     7831726
# 62                                        Unnamed: 63  2010.0   6864133.1
#
# [63 rows x 3 columns]

# %%
Population
# Out:
#    index          0
# 0   1960   88382881
# 1   1961   90816938
# 2   1962   93345489
# 3   1963   95962527
# 4   1964   98675061
# ..   ...        ...
# 57  2017  264498852
# 58  2018  267066843
# 59  2019  269582878
# 60  2020  271857970
# 61  2021  273753191
#
# [62 rows x 2 columns]

# %%
#Mengganti nama kolom pada DataFrame yang tersedia

Population.columns = ['Tahun', 'Population']
GDP = GDP[['Tahun','GDP']]

# %%
GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tahun   63 non-null     object
#  1   GDP     63 non-null     object
# dtypes: object(2)
# memory usage: 1.1+ KB

# %%
Population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tahun       62 non-null     object
#  1   Population  62 non-null     object
# dtypes: object(2)
# memory usage: 1.1+ KB

# %%
#Mengubah type data kolom

GDP = GDP.applymap(str)
Population = Population.applymap(str)

# %%
GDP['Tahun'] = GDP['Tahun'].str[:4]
GDP
# Out:
#    Tahun         GDP
# 0   1972        4548
# 1   1971        3794
# 2   1970      3340.2
# 3   1969      2718.3
# 4   1968      2096.7
# ..   ...         ...
# 58  2014  10569705.3
# 59  2013     9546134
# 60  2012   8615704.5
# 61  2011     7831726
# 62  2010   6864133.1
#
# [63 rows x 2 columns]

# %%
#Terhadap nilai - pada data diubah menjadi 0

GDP = GDP.apply(lambda x : x.str.replace("-","0", regex=True))

# %%
# Mengubah type data menjadi float, karena ketika dilakukan input perintah, type data str tidak dapat diubah langsung menjadi int.

GDP = GDP.applymap(float)
Population = Population.applymap(float)

# %%
#Mengubah type data menjadi Int sesuai dengan kebutuhan bentuk data dalam project

GDP['Tahun'] = GDP['Tahun'].apply(int)
Population['Tahun'] = Population['Tahun'].apply(int)

# %%
Population
# Out:
#     Tahun   Population
# 0    1960   88382881.0
# 1    1961   90816938.0
# 2    1962   93345489.0
# 3    1963   95962527.0
# 4    1964   98675061.0
# ..    ...          ...
# 57   2017  264498852.0
# 58   2018  267066843.0
# 59   2019  269582878.0
# 60   2020  271857970.0
# 61   2021  273753191.0
#
# [62 rows x 2 columns]

# %% [markdown]
# ### Sorting Value

# %%
# Data yang tersedia belum dalam bentuk yang urut. sehingga perintah sort value harus dilakukan

GDP = GDP.sort_values('Tahun', ascending = True)
GDP
# Out:
#     Tahun         GDP
# 12   1960       390.2
# 11   1961       470.1
# 10   1962      1335.1
# 9    1963      3208.8
# 8    1964      7133.5
# ..    ...         ...
# 54   2018  14838756.0
# 53   2019  15832657.2
# 52   2020  15438017.5
# 51   2021  16970789.2
# 50   2022         0.0
#
# [63 rows x 2 columns]

# %%
# Menghapus baris terakhir karena tidak diperlukan dan supaya dimensi data dari kedua dataframe sama

GDP = GDP.iloc[:-1]

# %% [markdown]
# ### Merger DataFrame

# %%
#Melakukan Merger pada Dataframe GDP dengan Dataframe Population menjadi Dataframe baru dengan nama Data_Master

Data_Master = GDP.merge(Population, left_on='Tahun', right_on='Tahun')

# %% [markdown]
# ### Pengecekan Dataframe baru yang telah diolah

# %%
#Menambah Kolom baru yaitu Growth Percentage pada DataFrame Data_Master

Data_Master["Growth_Percentage"]=Data_Master["GDP"].pct_change()

# %%
#Melihat Deskripsi data pada Dataframe Data_Master

Data_Master.describe()
# Out:
#              Tahun           GDP    Population  Growth_Percentage
# count    62.000000  6.200000e+01  6.200000e+01          61.000000
# mean   1990.500000  2.903404e+06  1.821599e+08           0.315510
# std      18.041619  4.863077e+06  5.706037e+07           0.497025
# min    1960.000000  3.159000e+02  8.838288e+07          -0.986677
# 25%    1975.250000  1.635270e+04  1.320402e+08           0.107992
# 50%    1990.500000  2.115237e+05  1.837606e+08           0.180659
# 75%    2005.750000  3.197983e+06  2.310494e+08           0.252549
# max    2021.000000  1.697079e+07  2.737532e+08           2.323754

# %%
Data_Master.head(15)
# Out:
#     Tahun      GDP   Population  Growth_Percentage
# 0    1960    390.2   88382881.0                NaN
# 1    1961    470.1   90816938.0           0.204767
# 2    1962   1335.1   93345489.0           1.840034
# 3    1963   3208.8   95962527.0           1.403415
# 4    1964   7133.5   98675061.0           1.223105
# 5    1965  23710.0  101157868.0           2.323754
# 6    1966    315.9  103561105.0          -0.986677
# 7    1967    847.8  106260749.0           1.683761
# 8    1968   2096.7  109138723.0           1.473107
# 9    1969   2718.3  112149246.0           0.296466
# 10   1970   3340.2  115228394.0           0.228783
# 11   1971   3794.0  118347135.0           0.135860
# 12   1972   4548.0  121504145.0           0.198735
# 13   1973   6753.4  124709058.0           0.484916
# 14   1974  10708.0  127945196.0           0.585572

# %%
#Mengecek Data yang duplicate

Data_Master.duplicated().sum()
# Out:
# 0

# %%
#Ekspor data ke dalam bentuk .csv

Data_Master.to_csv('Data_Master.csv')

# %%
#Membuat visualisasi terhadap Missing Value yang berada di Dataframe Data_Master

missingno.matrix(Data_Master)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Melakukan Univariate Analysis

# %% [markdown]
# ### Fungsi untuk melakukan Univariate Analysis

# %%
# Fungsi yang digunakan untuk Numerical Univariate Analysis
def num_uni_box_analysis(Data_Master, var, friendly_name):
  ax = sns.boxplot(data=Data_Master, x=var)
  ax.set_xticks(list(Data_Master[var].quantile([0,0.25,0.5,0.75,0.95,1])))
  ax.set_xlabel(friendly_name)
  ax.set_title(f'{friendly_name} Distribution Univariate Analysis', fontsize=20)
  ax.figure.set_size_inches(24,8)

def num_uni_hist_analysis(Data_Master, var, friendly_name):
  ax = sns.histplot(data=Data_Master ,x=var, stat='percent')
  ax.set_xlabel(friendly_name)
  ax.set_title(f'{friendly_name} Distribution Histogram', fontsize=20)
  ax.figure.set_size_inches(24,8)

# %% [markdown]
# ### Visualisasi Univariate Analysis

# %%
#Visualisasi Distribution Univariate Analysis (Box) pada Tahun

num_uni_box_analysis(Data_Master, 'Tahun', 'Tahun')
plt.show()

# %%
#Visualisasi Distribution Univariate Analysis (Histogram) pada Tahun

num_uni_hist_analysis(Data_Master, 'Tahun', 'Tahun')
plt.show()

# %%
#Visualisasi Distribution Univariate Analysis (Box) pada GDP

num_uni_box_analysis(Data_Master, 'GDP', 'GDP (dalam Miliar)')
plt.show()

# %%
#Visualisasi Distribution Univariate Analysis (Histogram) pada GDP

num_uni_hist_analysis(Data_Master, 'GDP', 'GDP (dalam Miliar)')
plt.show()

# %%
#Visualisasi Distribution Univariate Analysis (Boxplot) pada GDP

sns.boxplot(data=Data_Master['Growth_Percentage'], linewidth=2, color="red")
# Out:
# <AxesSubplot:>

# %%
#Visualisasi Distribution Univariate Analysis (Boxplot) pada Population

sns.boxplot(data=Data_Master['Population'], linewidth=2, color="skyblue")
# Out:
# <AxesSubplot:>

# %%
#Visualisasi Distribution Univariate Analysis (Boxplot) pada Dataframe Data_Master

sns.pairplot(Data_Master)
plt.show()

# %%
#Visualisasi korelasi pada setiap variable yang terdapat di Dataframe Data_Master

ax = sns.heatmap(Data_Master.corr(), annot=True, cmap='Reds')
ax.figure.set_size_inches(14,12)
plt.show()

# %% [markdown]
# ## MODELLING PART 1

# %% [markdown]
# ### Duplikasi Dataframe untuk dilakukan permodelan

# %%
GDP_model1 = GDP.copy()
GDP_model1.Tahun = pd.to_datetime(GDP_model1.Tahun, format='%Y')
GDP_model1.head()
# Out:
#         Tahun     GDP
# 12 1960-01-01   390.2
# 11 1961-01-01   470.1
# 10 1962-01-01  1335.1
# 9  1963-01-01  3208.8
# 8  1964-01-01  7133.5

# %% [markdown]
# ### Eksport Duplikasi Dataframe

# %%
#Eksport duplikasi dataframe ke dalam .csv

GDP_model1['GDP'].to_csv('GDP only.csv', index= False)

# %% [markdown]
# ### Visualisasi Dataframe

# %%
#Membuat visualisasi pergerakan GDP dari tahun 1960-2021

def plot_df(GDP_model1, x, y, title="", xlabel='Tahun', ylabel='GDP', dpi=100):
    plt.figure(figsize=(20,8), dpi=dpi)
    plt.plot(x, y, color='tab:orange')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
    

plot_df(GDP_model1, x=GDP_model1['Tahun'], y=GDP_model1['GDP'], title='GDP Indonesia 1960-2021')

# %%
#Defining Multiplicative or Additive Time Series - cari tahu definisinya lebih lanjut
#Kalo ada nilai negatif, maka bentuknya pasti berupa additive time series, bukan multiplicative

#from statsmodels.tsa.seasonal import seasonal_decompose
#from dateutil.parser import parse
#GDP_only = pd.read_csv('GDP only.csv')
#
## Multiplicative Decomposition 
#multiplicative_decomposition = seasonal_decompose(GDP_only, model='multiplicative', period=1)
#
## Additive Decomposition
#additive_decomposition = seasonal_decompose(GDP_only, model='additive', period=1)
#
## Plot
#plt.rcParams.update({'figure.figsize': (16,12)})
#
#multiplicative_decomposition.plot().suptitle('Multiplicative Decomposition', fontsize=16)
#plt.tight_layout(rect=[0, 0.03, 1, 0.95])
#
#additive_decomposition.plot().suptitle('Additive Decomposition', fontsize=16)
#plt.tight_layout(rect=[0, 0.03, 1, 0.95])
#
#plt.show()

# %% [markdown]
# ### Test Stationery Data

# %%
# Melakukan test stasioner terhadap data GDP menggunakan Augmented Dickey-Fuller

GDP_only = pd.read_csv('GDP only.csv')
passing_data=adfuller(GDP_only)

# %%
#Define the test
#Sumber: https://www.section.io/engineering-education/univariate-time-series-analysis-with-arima-in-python/
def adf_test(GDP):
    result=adfuller(GDP)
    labels = ['Test parameters', 'p-value','#Lags Used','Dataset observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("Dataset is stationary")
    else:
        print("Dataset is non-stationary ")

# %%
#Run the test
adf_test(GDP_only)
# Out:
# Test parameters : -4.825297145111437
# p-value : 4.8639106700036034e-05
# #Lags Used : 11
# Dataset observations : 50
# Dataset is stationary

# %% [markdown]
# ### Analisis Data GDP dalam menentukan order ARIMA yang harus dipakai

# %% [markdown]
# #### Penentuan Model dengan Manual interpreter

# %% [markdown]
# ##### Menentukan order Indifference (I)

# %%
plt.rcParams.update({'figure.figsize':(9,7), 'figure.dpi':120})

# Import data
df = pd.read_csv('GDP only.csv', names=['value'], header=0)

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(df.value); axes[0, 0].set_title('Original Series')
plot_acf(df.value, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(df.value.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(df.value.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(df.value.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(df.value.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# #### Menentukan order Auto Regression (AR)

# %%
# PACF plot of 1st differenced series
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df.value); axes[0].set_title('Original Series')
axes[1].set(ylim=(0,5))
plot_pacf(df.value.dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# #### Menentukan Moving Average (MA)

# %%
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2, sharex=True)
axes[0].plot(df.value); axes[0].set_title('Original Series')
axes[1].set(ylim=(0,1.2))
plot_acf(df.value.dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# ### Melakukan Permodelan ARIMA dan Visualisasi hasil

# %%
#Permodelan ARIMA dengan order (2,0,2)

model = ARIMA(df.value, order=(2,0,2))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   62
# Model:                 ARIMA(2, 0, 2)   Log Likelihood                -923.191
# Date:                Tue, 24 Jan 2023   AIC                           1858.383
# Time:                        23:20:59   BIC                           1871.146
# Sample:                             0   HQIC                          1863.394
#                                  - 62
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.903e+06    8.2e-07   3.54e+12      0.000     2.9e+06     2.9e+06
# ar.L1          1.9960      0.004    549.051      0.000       1.989       2.003
# ar.L2         -0.9980      0.004   -276.352      0.000      -1.005      -0.991
# ma.L1      -7.727e-05      3.108  -2.49e-05      1.000      -6.092       6.092
# ma.L2         -0.9999      0.043    -23.434      0.000      -1.084      -0.916
# sigma2      6.024e+10   5.16e-11   1.17e+21      0.000    6.02e+10    6.02e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                  11.78   Jarque-Bera (JB):               100.95
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):             470.36   Skew:                             2.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.35e+38. Standard errors may be unstable.

# %%
#Permodelan ARIMA dengan order (2,0,1)

model = ARIMA(df.value, order=(2,0,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                   62
# Model:                 ARIMA(2, 0, 1)   Log Likelihood                -866.297
# Date:                Tue, 24 Jan 2023   AIC                           1742.594
# Time:                        23:20:59   BIC                           1753.229
# Sample:                             0   HQIC                          1746.770
#                                  - 62
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.903e+06   3.45e-11   8.41e+16      0.000     2.9e+06     2.9e+06
# ar.L1          1.9842      0.031     64.339      0.000       1.924       2.045
# ar.L2         -0.9860      0.034    -29.276      0.000      -1.052      -0.920
# ma.L1         -0.6878      0.072     -9.583      0.000      -0.828      -0.547
# sigma2      7.009e+10   8.97e-13   7.82e+22      0.000    7.01e+10    7.01e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.66   Jarque-Bera (JB):               600.08
# Prob(Q):                              0.10   Prob(JB):                         0.00
# Heteroskedasticity (H):             483.75   Skew:                            -1.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.51e+38. Standard errors may be unstable.

# %%
#Melakukan pengecekan hasil residual dan densitas data

residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
#Uji Hasil forecast dengan 95% Confidence interval

plot_predict(model_fit, dynamic=False)
plt.show()

# %%
# Build Model
# model = ARIMA(train, order=(2,0,1))  
# sumber https://stackoverflow.com/questions/70223523/statsmodel-typeerror-fit-got-an-unexpected-keyword-argument-disp
#import statsmodels.api as smapi

#Create Training and Test
#train=df.value[:51]
#test=df.value[51:]
#
#model = sm.tsa.arima.ARIMA(train, order=(2,0,1))
#fitted = model.fit()
#
## Forecast
#fc, se, conf = fitted.forecast(3, alpha=0.05)  # 95% conf

# %% [markdown]
# ##### Menentukan model ARIMA dengan Out of Time Cross-Validation

# %%
# Make as pandas series
#fc_series = pd.Series(fc, index=test.index)
#lower_series = pd.Series(conf[:, 0], index=test.index)
#upper_series = pd.Series(conf[:, 1], index=test.index)
#
## Plot
#plt.figure(figsize=(12,5), dpi=100)
#plt.plot(train, label='training')
#plt.plot(test, label='actual')
#plt.plot(fc_series, label='forecast')
#plt.fill_between(lower_series.index, lower_series, upper_series, 
#                 color='k', alpha=.15)
#plt.title('Forecast vs Actuals')
#plt.legend(loc='upper left', fontsize=8)
#plt.show()

# %% [markdown]
# ##### Menentukan model ARIMA dengan Auto ARIMA Forecast

# %%
model = pm.auto_arima(df.value, start_p=1, start_q=1,
                      test='adf',       # otomatis menggunakan ADF Test untuk menentukan nilai 'd' yang optimal
                      max_p=3, max_q=3, # nilai p dan q (default = 3)
                      m=1,              # jumlah series dalam satu tahun
                      d=None,           # model menentukan nilai 'd'
                      seasonal=False,   # Tanpa Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=1672.036, Time=0.05 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1700.905, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1673.655, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1680.644, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1699.285, Time=0.02 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=1670.997, Time=0.06 sec
#  ARIMA(2,2,0)(0,0,0)[0] intercept   : AIC=1670.055, Time=0.02 sec
#  ARIMA(3,2,0)(0,0,0)[0] intercept   : AIC=1667.234, Time=0.06 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=1669.133, Time=0.12 sec
#  ARIMA(3,2,0)(0,0,0)[0]             : AIC=1667.216, Time=0.05 sec
#  ARIMA(2,2,0)(0,0,0)[0]             : AIC=1668.834, Time=0.01 sec
#  ARIMA(3,2,1)(0,0,0)[0]             : AIC=1668.949, Time=0.11 sec
#  ARIMA(2,2,1)(0,0,0)[0]             : AIC=1669.405, Time=0.19 sec
#
# Best model:  ARIMA(3,2,0)(0,0,0)[0]
# Total fit time: 0.782 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   62
# Model:               SARIMAX(3, 2, 0)   Log Likelihood                -829.608
# Date:                Tue, 24 Jan 2023   AIC                           1667.216
# Time:                        23:21:00   BIC                           1675.593
# Sample:                             0   HQIC                          1670.493
#                                  - 62
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9615      0.095    -10.121      0.000      -1.148      -0.775
# ar.L2         -0.7744      0.207     -3.736      0.000      -1.181      -0.368
# ar.L3         -0.4915      0.152     -3.236      0.001      -0.789      -0.194
# sigma2      6.263e+10   4.93e-12   1.27e+22      0.000    6.26e+10    6.26e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              1300.78
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):            2762.29   Skew:                            -3.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                        24.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.03e+37. Standard errors may be unstable.

# %% [markdown]
# Hasil menunjukkan 'SARIMAX Result' sebagai penamaan saja, selama Seasonality di-define False, tidak menggunakan seasonality
#
# Sumber: https://stackoverflow.com/questions/69528507/auto-arima-seasonal-false-but-got-sarimax

# %%
model.plot_diagnostics(figsize=(7,5))
plt.show()

# %% [markdown]
# #### Visualisasi Hasil Forecast

# %%
#sumber https://stackoverflow.com/questions/73112516/arimaresults-object-has-no-attribute-plot-predict-error

dta = df['value']
dta.index = pd.date_range(start='1960', end='2022', freq='A') #karena error sesuai dt di bawah data yang muncul 1970-2032 (jumlah data tetap 62 seperti jumlah awal)
res = ARIMA(dta, order=(2,0,1)).fit()
fig, ax = plt.subplots()
ax = dta.loc['1960':].plot(ax=ax)
plot_predict(res, '2012', '2032', ax=ax) #karena error maka seharusnya forecast dari (2012-2027)
plt.show()

# %%
# fit model
model = ARIMA(df, order=(2, 0, 2))
model_fit = model.fit()
# make prediction
hasil_prediksi = model_fit.predict(63, typ='levels')
print(hasil_prediksi)
# Out:
# 63    1.884863e+07
# dtype: float64
